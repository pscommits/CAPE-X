# %%
# !pip install ultralytics opencv-python matplotlib seaborn pandas scikit-learn
from ultralytics import YOLO

# %%
# Load YOLO base model
model = YOLO("yolo11n.pt")

# Train on crater dataset
results = model.train(
    data="data.yaml",   # path to yaml inside repo
    epochs=100,
    imgsz=640,
    batch=16,
    name="mercury_model"
)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.3.198 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.197 🚀 Python-3.10.10 torch-2.7.1+cu128 CUDA:0 (NVIDIA L4, 22813MiB)
# ...
